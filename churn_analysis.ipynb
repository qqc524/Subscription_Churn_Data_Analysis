# %% [markdown]
# <h1 style="text-align:center; font-size:40px; color:black;"> Exploring Subscription Churn Data </h1>
#
# <center>
#     <img src="https://cdn.corporatefinanceinstitute.com/assets/churn-rate-1024x683.jpeg" width="800" height="50">
# </center>
#
# ***
#
# <h1 style="font-size:32px;"> 📖 Dataset Introduction </h1>
#
# <div class="alert alert-block alert-success" style="padding: 2em; background-color: #fff; border-radius: 5em; border-width:4px; border-color: lightblue; color: black; font-size:18px; font-family: sans-serif; line-height: 1.7em;">
#
# This dataset comes from a video streaming service and represents a sample of subscriptions initiated in 2021. The data includes snapshots taken at a specific point in time before customers canceled their subscriptions. It is designed to help analyze patterns and trends associated with customer churn.
#
# The dataset provides valuable information that reflects customer behavior and decision-making, including:
#
# - Subscription details and timelines.
# - Patterns leading to cancellation, such as a lack of engagement, busy schedules, or a mismatch with customer needs.
# - Insights into retention challenges faced by subscription-based services.
#
# With this data, we will explore and understand the key factors behind customer churn using exploratory data analysis (EDA). This will help create better strategies for improving customer retention.
#
# </div>

# %% [markdown]
# <h1 style="font-size:32px">🔬 Feature Description </h1>

# %% [markdown]
# | Column_Name             | Description                                                                                       |
# |-------------------------|---------------------------------------------------------------------------------------------------|
# | AccountAge              | Age of the user's account in months.                                                             |
# | MonthlyCharges          | The monthly subscription fee charged to the user.                                                |
# | TotalCharges            | Total fees accumulated over the account's lifetime.                                              |
# | SubscriptionType        | The plan selected by the user (e.g., Basic, Standard, Premium).                                   |
# | PaymentMethod           | The user's chosen payment method.                                                                |
# | PaperlessBilling        | Whether the user has opted for paperless billing (Yes/No).                                        |
# | ContentType             | The type of content preferred by the user (e.g., Movies, TV Shows, Both).                        |
# | MultiDeviceAccess       | Indicates if the user has access to the service on multiple devices (Yes/No).                     |
# | DeviceRegistered        | The type of device the user registered for accessing the service (e.g., TV, Mobile, Tablet, Computer). |
# | ViewingHoursPerWeek     | Average weekly hours spent watching content.                                                     |
# | AverageViewingDuration  | The average length of a single viewing session in minutes.                                        |
# | ContentDownloadsPerMonth| The number of downloads by the user in a month.                                                  |
# | GenrePreference         | The user's preferred content genre.                                                              |
# | UserRating              | The user's rating of the service (1–5 scale).                                                    |
# | SupportTicketsPerMonth  | Monthly count of support tickets raised by the user.                                             |
# | Gender                  | The user's gender (Male/Female).                                                                 |
# | WatchlistSize           | Total items saved in the user's watchlist.                                                       |
# | ParentalControl         | Whether parental controls are active (Yes/No).                                                   |
# | SubtitlesEnabled        | Whether subtitles are enabled for the user (Yes/No).                                             |
# | CustomerID              | Unique identifier assigned to each customer.                                                     |
# | Churn                   | Target variable that shows if the user has churned (1 = churned, 0 = not churned).               |

# %% [markdown]
# <h1 style="font-size:32px">👀 Exploratory Data Analysis (EDA) </h1>

# %% [markdown]
# <span style="font-size:18px;">
#
# Exploratory Data Analysis (EDA) is an important step in any data project. It helps us to understand the dataset, summarize key points, and find patterns or trends that can guide us in further analysis or modeling.
# </span>
#
# #### 🎯 **Objectives**
#
# - Learn more about the data.
# - Visualize the distributions, relationships, and patterns within the data.
# - Find missing values, outliers, and problems in the data.
#
# Now, let's dive into the process of EDA and uncover key findings! 🚀

# %% [markdown]
# <div style="border-radius: 10px; border: purple solid; padding: 10px; background-color: #; font-size: 100%; text-align: center;">
#
# ## **Import Libraries and Load Data**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
churn = pd.read_csv('churn.csv')

# %% [markdown]
# <div style="border-radius: 10px; border: purple solid; padding: 10px; background-color: #; font-size: 100%; text-align: center;">
#
# ## **About the Dataset**

# %%
print(f"This Dataset contains \033[1m{churn.shape[0]}\033[0m rows and \033[1m{churn.shape[1]}\033[0m columns.")
# Out:
# This Dataset contains 243787 rows and 21 columns.

# %%
#Let's check the first & last 5 samples of the data 
print('First 5 rows:', '\n')
churn.head()
# Out:
# First 5 rows:
#    AccountAge  MonthlyCharges  TotalCharges SubscriptionType  \
# 0          20       11.055215    221.104302          Premium
# 1          57        5.175208    294.986882            Basic
# 2          73       12.106657    883.785952            Basic
# 3          32        7.263743    232.439774            Basic
# 4          57       16.953078    966.325422          Premium
#
#       PaymentMethod PaperlessBilling ContentType MultiDeviceAccess  \
# 0      Mailed check               No        Both                No
# 1       Credit card              Yes      Movies                No
# 2      Mailed check              Yes      Movies                No
# 3  Electronic check               No    TV Shows                No
# 4  Electronic check              Yes    TV Shows                No
#
#   DeviceRegistered  ViewingHoursPerWeek  ...  ContentDownloadsPerMonth  \
# 0           Mobile            36.758104  ...                        10
# ...

# %%
print('Last 5 rows:', '\n')
churn.tail()
# Out:
# Last 5 rows:
#         AccountAge  MonthlyCharges  TotalCharges SubscriptionType  \
# 243782          77        9.639902    742.272460            Basic
# 243783         117       13.049257   1526.763053          Premium
# 243784         113       14.514569   1640.146267          Premium
# 243785           7       18.140555    126.983887          Premium
# 243786          90       11.593774   1043.439704          Premium
#
#         PaymentMethod PaperlessBilling ContentType MultiDeviceAccess  \
# 243782   Mailed check               No      Movies                No
# 243783    Credit card               No    TV Shows               Yes
# 243784    Credit card              Yes    TV Shows                No
# 243785  Bank transfer              Yes    TV Shows                No
# 243786   Mailed check               No        Both                No
#
#        DeviceRegistered  ViewingHoursPerWeek  ...  ContentDownloadsPerMonth  \
# ...

# %%
# Basic information about the dataset
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243787 entries, 0 to 243786
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   AccountAge                243787 non-null  int64
#  1   MonthlyCharges            243787 non-null  float64
#  2   TotalCharges              243787 non-null  float64
#  3   SubscriptionType          243787 non-null  object
#  4   PaymentMethod             243787 non-null  object
#  5   PaperlessBilling          243787 non-null  object
#  6   ContentType               243787 non-null  object
#  7   MultiDeviceAccess         243787 non-null  object
#  8   DeviceRegistered          243787 non-null  object
#  9   ViewingHoursPerWeek       243787 non-null  float64
#  10  AverageViewingDuration    243787 non-null  float64
#  11  ContentDownloadsPerMonth  243787 non-null  int64
#  12  GenrePreference           243787 non-null  object
# ...

# %% [markdown]
# ### Missing Values

# %%
# Check for any missing values in the dataset
churn.isnull().sum()
# Out:
# AccountAge                  0
# MonthlyCharges              0
# TotalCharges                0
# SubscriptionType            0
# PaymentMethod               0
# PaperlessBilling            0
# ContentType                 0
# MultiDeviceAccess           0
# DeviceRegistered            0
# ViewingHoursPerWeek         0
# AverageViewingDuration      0
# ContentDownloadsPerMonth    0
# GenrePreference             0
# UserRating                  0
# SupportTicketsPerMonth      0
# Gender                      0
# WatchlistSize               0
# ParentalControl             0
# SubtitlesEnabled            0
# CustomerID                  0
# Churn                       0
# dtype: int64

# %% [markdown]
# ---
# <span style="color: blue;">No missing values across all columns.</span>

# %% [markdown]
# ### Checking Duplicates

# %%
print('The duplicated rows in the dataset:', churn.duplicated().sum())
# Out:
# The duplicated rows in the dataset: 0

# %% [markdown]
# <div style="border-radius: 10px; border: purple solid; padding: 10px; background-color: #; font-size: 100%; text-align: center;">
#
# ## **Descriptive Statistics**

# %%
churn.describe().round(2).T
# Out:
#                              count    mean     std   min     25%     50%  \
# AccountAge                243787.0   60.08   34.29  1.00   30.00   60.00
# MonthlyCharges            243787.0   12.49    4.33  4.99    8.74   12.50
# TotalCharges              243787.0  750.74  523.07  4.99  329.15  649.88
# ViewingHoursPerWeek       243787.0   20.50   11.24  1.00   10.76   20.52
# AverageViewingDuration    243787.0   92.26   50.51  5.00   48.38   92.25
# ContentDownloadsPerMonth  243787.0   24.50   14.42  0.00   12.00   24.00
# UserRating                243787.0    3.00    1.16  1.00    2.00    3.00
# SupportTicketsPerMonth    243787.0    4.50    2.87  0.00    2.00    4.00
# WatchlistSize             243787.0   12.02    7.19  0.00    6.00   12.00
# Churn                     243787.0    0.18    0.39  0.00    0.00    0.00
#
#                               75%      max
# AccountAge                  90.00   119.00
# MonthlyCharges              16.24    19.99
# ...

# %% [markdown]
# ### Summary of Categorical Features

# %%
churn.describe(include=['object']).T
# Out:
#                     count  unique               top    freq
# SubscriptionType   243787       3          Standard   81920
# PaymentMethod      243787       4  Electronic check   61313
# PaperlessBilling   243787       2                No  121980
# ContentType        243787       3              Both   81737
# MultiDeviceAccess  243787       2                No  122035
# DeviceRegistered   243787       4          Computer   61147
# GenrePreference    243787       5            Comedy   49060
# Gender             243787       2            Female  121930
# ParentalControl    243787       2               Yes  122085
# SubtitlesEnabled   243787       2               Yes  122180
# CustomerID         243787  243787        CB6SXPNVZA       1

# %% [markdown]
# <div style="border-radius: 10px; border: purple solid; padding: 10px; background-color: #; font-size: 100%; text-align: center;">
#
# ## **Churn Distribution**

# %% [markdown]
# <span style="font-size:18px">
# "Churn" is the target variable, so understanding its distribution is critical.
#
# </span>

# %%
# Calculate churn proportions
churn_counts = churn['Churn'].value_counts()
labels = ['Not Churned (0)', 'Churned (1)']
colors = ['lightblue', 'salmon']

# Create pie chart
plt.figure(figsize=(8, 6))
plt.pie(churn_counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors, textprops={'fontsize': 10})
plt.title('Churn Distribution', fontsize=14)
plt.show()

# %% [markdown]
# <div style="border-radius: 10px; border: purple solid; padding: 10px; background-color: #; font-size: 100%; text-align: center;">
#
# ## **Categorical Feature Analysis**

# %%
# List of categorical column names

churn.select_dtypes(include=['object']).columns.tolist()
# Out:
# ['SubscriptionType',
#  'PaymentMethod',
#  'PaperlessBilling',
#  'ContentType',
#  'MultiDeviceAccess',
#  'DeviceRegistered',
#  'GenrePreference',
#  'Gender',
#  'ParentalControl',
#  'SubtitlesEnabled',
#  'CustomerID']

# %%
categorical_columns = categorical_columns = ['SubscriptionType', 'PaymentMethod', 'PaperlessBilling', 'ContentType', 
                       'MultiDeviceAccess', 'DeviceRegistered', 'GenrePreference', 'Gender', 
                       'ParentalControl', 'SubtitlesEnabled']

# %% [markdown]
# Exclue "CustomerID" as it doesn’t contribute meaningfully to the analysis.

# %% [markdown]
# ### Feature Distributions

# %%
# Visualize the categorical feature distributions
num_columns = len(categorical_columns)
rows = (num_columns // 2) + (num_columns % 2)  
cols = 2

fig, axes = plt.subplots(rows, cols, figsize=(15, rows * 5))  # Adjust figure size based on rows
axes = axes.flatten() if isinstance(axes, np.ndarray) else [axes]  # Ensure axes is iterable

# Plot each categorical feature
for i, col in enumerate(categorical_columns):
    churn[col].value_counts().plot(kind='bar', color= '#f6ddcc', edgecolor='black', ax=axes[i])
    axes[i].set_title(f'{col} Distribution', fontsize=14)
    axes[i].set_xlabel(col, fontsize=12)
    axes[i].set_ylabel('Count', fontsize=12)
    axes[i].tick_params(axis='x', rotation=45)


# Turn off unused subplot axes
for i in range(num_columns, len(axes)):
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Categorical Features vs Churn
#
# <span style="font-size:16px">
# The analysis explores how each categorical feature relates to the target variable, Churn.
# Bar plots are used to visualize the distribution of each category within a feature, comparing the count of users who churned (1) versus those who did not (0). These insights help identify patterns and relationships between customer attributes and churn behavior.
# </span>

# %%
# Bar plots for categorical features
for column in categorical_columns:
    plt.figure(figsize=(10, 6))
    ax = sns.countplot(x=column, hue='Churn', data=churn, palette=colors)
    
    # Add count annotations
    for container in ax.containers:
        ax.bar_label(container, fmt='%d', label_type='edge', fontsize=10)
    
    plt.title(f'{column} vs Churn', fontsize=14)
    plt.xlabel(column, fontsize=12)
    plt.ylabel('Count', fontsize=12)
    
    # Move the legend outside the plot
    plt.legend(title='Churn', labels=labels, fontsize=12, bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.xticks(rotation=45)
    plt.tight_layout()  # Ensure the layout is tight to prevent clipping
    plt.show()

# %% [markdown]
# <div style="border-radius: 10px; border: purple solid; padding: 10px; background-color: #; font-size: 100%; text-align: center;">
#
# ## **Numerical Feature Analysis**

# %%
#list of numerical column names
churn.select_dtypes(include=['int64', 'float64']).columns.tolist()
# Out:
# ['AccountAge',
#  'MonthlyCharges',
#  'TotalCharges',
#  'ViewingHoursPerWeek',
#  'AverageViewingDuration',
#  'ContentDownloadsPerMonth',
#  'UserRating',
#  'SupportTicketsPerMonth',
#  'WatchlistSize',
#  'Churn']

# %%
numerical_columns = ['AccountAge', 'MonthlyCharges', 'TotalCharges', 'ViewingHoursPerWeek',
                   'AverageViewingDuration', 'ContentDownloadsPerMonth', 'UserRating', 
                   'SupportTicketsPerMonth', 'WatchlistSize']

# %% [markdown]
# <span style="font-size:15px;">
# Exclue "Churn" as it doesn’t contribute meaningfully to the analysis.
# </span>

# %% [markdown]
# ### Feature Distributions

# %%
num_columns = len(numerical_columns)
rows = (num_columns // 2) + (num_columns % 2)
cols = 2

fig, axes = plt.subplots(rows, cols, figsize=(15, rows * 5))  # Adjust figure size based on rows
axes = axes.flatten() if isinstance(axes, np.ndarray) else [axes]  # Ensure axes is iterable


# Plot each numerical feature
for i, col in enumerate(numerical_columns):
    churn[col].plot(kind='hist', color="#d5f5e3", edgecolor='black', ax=axes[i], bins=20)
    axes[i].set_title(f'{col} Distribution', fontsize=14)
    axes[i].set_xlabel(col, fontsize=12)
    axes[i].set_ylabel('Frequency', fontsize=12)

# Turn off unused subplot axes
for i in range(num_columns, len(axes)):
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Boxplot of Features Distribution

# %% [markdown]
# <span style="font-size:16px;">
# A boxplot is a graphical representation of the distribution of a dataset. It is used to visually summarize the spread, center, and outliers in the data.
# </span>
#
# #### Why We Use a Boxplot
# Boxplots are useful for:
# - **Detecting outliers**: Data points outside the whiskers of the box are considered outliers.
# - **Understanding the spread** of the data: It shows the range and variation of the data.
# - **Comparing distributions**: It helps compare data from different categories or groups.
#
#
# #### The Five-Number Summary
#
# A boxplot is made using a **five-number summary**, which summarizes the dataset in a simple way:
#
# - **Minimum**: The smallest value in the dataset.
# - **First Quartile (Q1)**: The middle value of the lower half of the data. It represents the **25th percentile**.
# - **Median (Q2)**: The middle value that divides the data into two equal halves.
# - **Third Quartile (Q3)**: The middle value of the upper half of the data. It represents the **75th percentile**.
# - **Maximum**: The largest value in the dataset.

# %%
# Loop through each numeric column
for i, column in enumerate(numerical_columns):
    # Create a boxplot for each column
    plt.figure(figsize=(8, 6))
    
    # Plot boxplot
    ax = sns.boxplot(y=churn[column], color='lightcoral')

    # Title and labels
    plt.title(f'Boxplot of {column}', fontsize=14)
    plt.xlabel(column, fontsize=12)
    plt.ylabel('Value', fontsize=12)

    # Add details for the 5-number summary and outliers
    Q1 = churn[column].quantile(0.25)
    Q3 = churn[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = churn[column][(churn[column] < lower_bound) | (churn[column] > upper_bound)]

    # Annotate outliers in the plot
    if len(outliers) > 0:
        plt.scatter([0] * len(outliers), outliers, color='blue', label='Outliers')

    # Add 5-number summary and outlier count text outside the graph
    text_str = (f"Q1: {Q1:.2f}\nQ3: {Q3:.2f}\nIQR: {IQR:.2f}\n"
                f"Minimum: {lower_bound:.2f}\nMaximum: {upper_bound:.2f}\n"
                f"# of Outliers: {len(outliers)}")
    
    plt.text(1.05, 0.5, text_str, transform=ax.transAxes, fontsize=12,
             verticalalignment='center', horizontalalignment='left', bbox=dict(facecolor='white', alpha=0.8))

    # Show the plot
    plt.tight_layout()
    plt.show()

# %% [markdown]
# <div style="border-radius: 10px; border: purple solid; padding: 10px; background-color: #; font-size: 100%; text-align: center;">
#
# ## **Correlation Heatmap for Numeric Variables**

# %% [markdown]
# Correlation Coefficient:
#
# - 1: Perfect positive correlation
# - 0: No correlation
# - -1: Perfect negative correlation

# %%
# Calculate correlation matrix for numeric variables
correlation_matrix = churn.corr(numeric_only=True)


# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True, square=True, linewidths=0.5)
plt.title("Correlation Heatmap for Numeric Variables", fontsize=14)
plt.xticks(fontsize=10, rotation=65)
plt.yticks(fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# <span style="font-size:16px;">
# The correlation heatmap visually represents the relationships between numerical variables in the dataset. Most correlations are close to 0, indicating weak or no linear relationships among the variables. This suggests that the numerical features are generally independent of one another.
# </span>

# %% [markdown]
# <div style="border-radius: 10px; border: purple solid; padding: 10px; background-color: #; font-size: 100%; text-align: center;">
#
# ## **Feature Interaction with Churn**

# %% [markdown]
# ### Taking a closer look at the correlation between Churn and other variables:

# %%
# Calculate correlation with Churn
correlation_with_churn = churn.corr(numeric_only=True)['Churn'].sort_values()

# Plot the correlation as a bar chart
fig, ax = plt.subplots(figsize=(10, 8))
bars = ax.bar(
    correlation_with_churn.drop('Churn').index, 
    correlation_with_churn.drop('Churn'), 
    color='lightcoral', 
    edgecolor='black'
)

# Add annotations for correlation rates
ax.bar_label(bars, fmt='%.2f', fontsize=10, label_type='edge')

# Add titles and labels
ax.set_title('Correlation of Numeric Variables with Churn', fontsize=14)
ax.set_xlabel('Features', fontsize=12)
ax.set_ylabel('Correlation Coefficient', fontsize=12)
ax.tick_params(axis='x', labelrotation=45, labelsize=10) 
plt.tight_layout()  
plt.show()

# %% [markdown]
# ### Insights:
#
# - The weak correlations suggest that no single numeric variable has a strong direct relationship with Churn.
# - **AccountAge, ViewingHoursPerWeek, and AverageViewingDuration** show slight negative correlations with Churn, indicating that longer engagement may reduce churn risk.
# - **MonthlyCharges and SupportTicketsPerMonth** show slight positive correlations, suggesting that higher charges or frequent support issues might contribute to churn.

# %% [markdown]
# ### <u>AccountAge vs Churn:</u>
#
# **AccountAge (-0.20):** A weak negative correlation suggests that customers with longer account ages might be less likely to churn.

# %%
plt.figure(figsize=(8, 6))
ax = sns.boxplot(x='Churn', y='AccountAge', data=churn, hue='Churn', palette=colors, legend=False)

# Calculate the median values for both groups (Churned and Not Churned)
medians = churn.groupby('Churn')['AccountAge'].median()

# Annotate the medians on the boxplot
for i, median in enumerate(medians):
    ax.text(i, median, f'{median:.2f}', horizontalalignment='center', size=12, color='black', fontweight='bold')

# Plot title and labels
plt.title('AccountAge vs Churn', fontsize=14)
plt.xlabel('Churn', fontsize=12)
plt.ylabel('Account Age', fontsize=12)

# Update x-axis tick labels
plt.xticks([0, 1], ['Not Churned', 'Churned'])

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# <span style="font-size:16px">The <b>median difference</b> of <b>65 vs 40</b> suggests that customers who have not churned tend to have a higher Account Age compared to those who have churned. This could indicate that customers who have been with the company longer are <u>less likely to churn</u>.</span>

# %% [markdown]
# ### <u>MonthlyCharges vs. Churn:</u>
#
# **MonthlyCharges (0.10):** A weak positive correlation hints at customers with higher monthly charges being slightly more likely to churn.

# %%
plt.figure(figsize=(8, 6))

# Plot the KDE for Churned vs Not Churned
sns.kdeplot(data=churn[churn['Churn'] == 0], x='MonthlyCharges', fill=True, color='skyblue', label='Not Churned', alpha=0.5)
sns.kdeplot(data=churn[churn['Churn'] == 1], x='MonthlyCharges', fill=True, color='lightcoral', label='Churned', alpha=0.5)

# Add labels and title
plt.title('MonthlyCharges vs Churn (KDE Plot)', fontsize=14)
plt.xlabel('Monthly Charges', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.legend(title='Churn', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# <span style="font-size:16px">Customers with higher monthly charges are <strong>more likely to churn</strong>. This suggests that, as the monthly charges increase, the likelihood of a customer leaving the service increases as well.</span>
